# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
df= sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(data=df, x='total_bill', y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# split the data into X and y
X= df[['total_bill']]
scalar=MinMaxScaler()
X= scalar.fit_transform(X)
y= df['tip']

# %%
# split the data into test and train
X_train, X_test, y_train, y_test= train_test_split(X, y, test_size=0.2, train_size=0.8)

# %%
# call the model
model= LinearRegression()

# %%
# train the model
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# take out model intercept and slope and make an equation
print(model.intercept_)
print(model.coef_)
print('y= ', model.intercept_, '+', model.coef_, '* X')
# Out:
# 1.3126484161790457
# [4.78818358]
# y=  1.3126484161790457 + [4.78818358] * X

# %%
X_test
# Out:
# array([[0.17113532],
#        [0.27691663],
#        [0.37892752],
#        [0.15207373],
#        [0.32006703],
#        [0.56095517],
#        [0.18747382],
#        [0.31881022],
#        [0.27042313],
#        [0.50544617],
#        [0.25994973],
#        [0.14390448],
#        [0.40134059],
#        [0.1575199 ],
#        [0.13573523],
#        [0.20297444],
#        [0.65416841],
#        [0.31776288],
#        [0.6248429 ],
#        [0.68621701],
#        [0.14662757],
#        [0.27084206],
#        [0.29723502],
#        [0.94679514],
#        [0.50712191],
#        [0.26686217],
#        [0.3640553 ],
#        [0.53142019],
#        [0.05613741],
#        [0.21617093],
#        [0.        ],
#        [0.30812736],
#        [0.21679933],
#        [0.1522832 ],
#        [0.359447  ],
#        [0.19710934],
#        [0.53372434],
#        [0.17846669],
#        [0.49266862],
#        [0.5437788 ],
#        [0.21868454],
#        [0.27754504],
#        [0.30414747],
#        [0.32760788],
#        [0.2764977 ],
#        [0.41223293],
#        [0.3261416 ],
#        [0.31860075],
#        [0.24633431]])

# %%
# Predict
y_pred= model.predict(X_test)

# %%
y_pred
# Out:
# array([2.13207573, 2.63857609, 3.12702297, 2.04080537, 2.84518811,
#        3.99860477, 2.21030747, 2.83917029, 2.60748399, 3.73281745,
#        2.55733544, 2.0016895 , 3.23434086, 2.06688261, 1.96257363,
#        2.28452732, 4.44492687, 2.83415543, 4.30451093, 4.59838143,
#        2.01472812, 2.60948993, 2.73586427, 5.84607737, 3.74084122,
#        2.59043348, 3.05581203, 3.85718586, 1.58144465, 2.34771449,
#        1.31264842, 2.78801877, 2.35072341, 2.04180834, 3.03374666,
#        2.25644413, 3.86821854, 2.16717971, 3.67163622, 3.91636115,
#        2.35975015, 2.641585  , 2.76896232, 2.88129507, 2.63657014,
#        3.28649536, 2.87427427, 2.83816732, 2.49214232])

# %%
# evalute the model:
print('MSE =', mean_squared_error(y_test, y_pred))
print('R2 =', r2_score(y_test, y_pred))
print('RMSE= ', np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# MSE = 0.7512253502521966
# R2 = 0.5947185630914492
# RMSE=  0.8667325713576227

# %%
# plot the model and data
plt.scatter(X_test, y_test)
plt.plot(X_test, y_pred, color='red')
plt.show()
