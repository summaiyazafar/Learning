# %% [markdown]
# ## Heirarchical Clustering:
# is a method of grouping data into disjoint subsets of similar data. It is a non-parametric method that is used when the number of clusters is known in advance. It is also used to find clusters in data that is not normally distributed.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import AgglomerativeClustering
import scipy.cluster.hierarchy as sch
from sklearn.datasets import make_blobs

# Generate a random dataset with 100 samples and 3 features
X, y= make_blobs(n_samples=100, centers=11, n_features=3, random_state=42)

# Perform hierarchical clustering with the AgglomerativeClustering Algorithm
clustering= AgglomerativeClustering(n_clusters=3, linkage='ward')
clustering.fit(X)

# Plot the dendrogram
plt.figure(figsize=(10, 7))
plt.title('Dandrogram')
dendrogram= sch.dendrogram(sch.linkage(X, method='ward'))
plt.show()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import AgglomerativeClustering
import scipy.cluster.hierarchy as sch
from sklearn.datasets import load_iris

df= sns.load_dataset('tips')

# Generate a random dataset with 100 samples and 3 features
X= df[['total_bill', 'size', 'tip']]

# Perform hierarchical clustering with the AgglomerativeClustering Algorithm
clustering= AgglomerativeClustering(n_clusters=3, linkage='ward')
clustering.fit(X)

# Plot the dendrogram
plt.figure(figsize=(10, 7))
plt.title('Dandrogram')
dendrogram= sch.dendrogram(sch.linkage(X, method='ward'))
plt.show()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import AgglomerativeClustering
import scipy.cluster.hierarchy as sch
from scipy.cluster.hierarchy import dendrogram, linkage

# load the tip datasetvfrom seaborn
df= sns.load_dataset('tips')

# Select relevant features for clustering
features= ['total_bill', 'tip']

# Extract the selected features from the dataset
X= df[features]

# Perform Agglomorative Clustering
n_clusters=5
agg_cluster= AgglomerativeClustering(n_clusters=n_clusters)
agg_labels= agg_cluster.fit_predict(X)

# Add cluster labels to the dataset
df['cluster']= agg_labels

# Visualize the clusters
sns.scatterplot(data=df, x='total_bill', y='tip', hue='cluster', palette='viridis')
plt.title('Agglomerative Clustering on tip dataset')
plt.xlabel('Total Bill')
plt.ylabel('Tip')
plt.show()

# Plot the dendrogram
dendrogram(linkage(X, method='ward'))
plt.title('Dendrogram')
plt.xlabel('Samples')
plt.ylabel('Distance')
plt.show()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import AgglomerativeClustering
import scipy.cluster.hierarchy as sch
from scipy.cluster.hierarchy import dendrogram, linkage

# load the tip datasetvfrom seaborn
df= sns.load_dataset('tips')

# Select relevant features for clustering
features= ['total_bill', 'tip', 'size']

# Extract the selected features from the dataset
X= df[features]

# Compute the linkage matrix
linkage_matrix= linkage(X, method='ward')

# Plot the dendrogram
dendrogram(linkage(X, method='ward'))
plt.title('Dendrogram')
plt.xlabel('Samples')
plt.ylabel('Distance')
plt.show()

# Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(X, cmap='coolwarm')
plt.title('Heatmap')
plt.xlabel('Features')
plt.ylabel('Samples')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage

# Load the tips dataset from seaborn
tips= sns.load_dataset('tips')

# Select relevant features for clustering
features= ['total_bill', 'tip', 'size']

# Extract the selected features from the dataset
X= df[features]

# Transpose the data matrix
x_transpose= X.transpose()

# Compare the linkage matrix
linkage_matrix= linkage(x_transpose, method= 'ward')

# Plot the dendrogram
plt.figure(figsize=(10, 7))
dendrogram(linkage_matrix)
plt.title('Dendrogram Based on Features')
plt.xlabel('Features')
plt.ylabel('Distance')
# Out:
# Text(0, 0.5, 'Distance')
