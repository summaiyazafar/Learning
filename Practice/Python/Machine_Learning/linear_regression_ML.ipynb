# %% [markdown]
# # Linear Regression:

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
#load the data
data= sns.load_dataset('tips')
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(data=data, x='total_bill', y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# split the data into X and y
X= data[['total_bill']]
# scale the total_bill
scalar=MinMaxScaler()
y= data['tip']

# %%
# split the data into train and test
X_train,X_test, y_train,  y_test= train_test_split(X, y, train_size=0.8)

# %%
# call the model
model= LinearRegression()

# %%
# train the model
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# take out model intercept and slop, make an equation
print(model.intercept_)
print(model.coef_)
print('y= ', model.intercept_, '+', model.coef_, '* X')
# Out:
# 0.8086249157183714
# [0.11365071]
# y=  0.8086249157183714 + [0.11365071] * X

# %%
X_test
# Out:
#      total_bill
# 120       11.69
# 205       16.47
# 73        25.28
# 86        13.03
# 1         10.34
# 189       23.10
# 140       17.47
# 50        12.54
# 202       13.00
# 33        20.69
# 81        16.66
# 179       34.63
# 104       20.92
# 80        19.44
# 156       48.17
# 23        39.42
# 215       12.90
# 95        40.17
# 102       44.30
# 37        16.93
# 0         16.99
# 235       10.07
# 163       13.81
# 113       23.95
# 127       14.52
# 159       16.49
# 184       40.55
# 59        48.27
# 128       11.38
# 19        20.65
# 233       10.77
# 180       34.65
# 236       12.60
# 182       45.35
# 176       17.89
# 213       13.27
# 5         25.29
# 72        26.86
# 94        22.75
# 123       15.95
# 239       29.03
# 178        9.60
# 97        12.03
# 8         15.04
# 134       18.26
# 177       14.48
# 30         9.55
# 69        15.01
# 241       22.67

# %%
# predict
y_pred= model.predict(X_test)# column diya or usko perdict kiya

# %%
y_pred
# Out:
# array([2.13720174, 2.68045214, 3.68171491, 2.28949369, 1.98377328,
#        3.43395636, 2.79410285, 2.23380484, 2.28608417, 3.16005814,
#        2.70204578, 4.74434907, 3.18619781, 3.01799475, 6.28317971,
#        5.28873598, 2.2747191 , 5.37397401, 5.84335145, 2.73273147,
#        2.73955051, 1.95308758, 2.37814125, 3.53055947, 2.45883325,
#        2.68272515, 5.41716128, 6.29454478, 2.10197002, 3.15551212,
#        2.03264308, 4.74662208, 2.24062389, 5.9626847 , 2.84183615,
#        2.31676986, 3.68285142, 3.86128304, 3.39417861, 2.62135377,
#        4.10790508, 1.89967175, 2.17584298, 2.51793162, 2.88388691,
#        2.45428722, 1.89398921, 2.5145221 , 3.38508655])

# %%
# check the error chances
# evalute the model
print('MSE= ', mean_squared_error(y_test, y_pred))
print('R2= ', r2_score(y_test, y_pred))
print('RMSE =', np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# MSE=  1.2379371347760437
# R2=  0.38804971986475467
# RMSE = 1.112626233187068

# %%
# plot the model
plt.scatter(X_test, y_test)
plt.plot(X_test, y_pred, color='blue')
plt.show()

# %% [markdown]
# # Multi-linear Regression:

# %%
# split the data into X and y
X= data[['total_bill', 'smoker']] # just one change that have two values777
# scale the total_bill
scalar=MinMaxScaler()
y= data['tip']
